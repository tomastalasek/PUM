% %% [markdown]
% # Domácí úkol 6
%
% Studenti, kteří byli na výuce musi vyřešit celkem čtyři z šesti domácích úkolů. Studenti, kteří na výuce absentovali musí vyřešit všechny domácí úkoly.

% %% [markdown]
% ## Příklad 1
%
% Vysvětlete, jak se došlo ke vzorci v podkapitole "Modifikace 3 - obsah kruhu pomocí obsahu pravidelného opsaného N-úhelníku" u výpočtu obsahu kruhu. Tj. vysvětlete, proč je v následujícím kódu použit vzorec $S=r^2\cdot\tan(\gamma)$

% %%
%počet dělení
N = 1000000
r=1

uhel=pi/N

obsah=r^2*tan(uhel)

obsah=obsah*N
% Out:
% N = 1000000
% r = 1
% uhel = 3.1416e-06
% obsah = 3.1416e-06
% obsah = 3.1416
